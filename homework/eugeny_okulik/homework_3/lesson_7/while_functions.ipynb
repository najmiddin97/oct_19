# %%
a = 1
b = 5
c = 4
d = 7
y = 0

main_number = 47

def calc(numb):
    if y == 0:
        return numb
    else:
        result = numb + main_number
        return result


print(calc(b))
calc(b)
calc(c)
calc(d)
_ = 1
# Out:
# 5

# %%
def hello():
    a = 12

print(hello())
# Out:
# None

# %%
def print_words(first, second, third, fourth, fifth):
    print(f'The fist word is {first}, second word is {second}, {third}, {fourth}, {fifth}')
print_words('one', 'two', 'three', 'four', 'five')
print_words(fifth='five', third='three', fourth='four', first='one', second='two')
# Out:
# The fist word is one, second word is two, three, four, five
# The fist word is one, second word is two, three, four, five

# %%
def power(number, degree=2):
    return number ** degree
print (power(2))
print (power(2, 3))
# Out:
# 4
# 8

# %%
def summ_all(*args):
    #print(args)
    #result = 0
    #for x in args:
        #result += x
    #return result
    return sum(args)

print(summ_all(1, 4, 6, 3))
# Out:
# 14

# %%
def price_list(title, price):
    print(f'Product {title} price is {price}')

price_list('Iphone', 2500)
price_list('Laptop', 3500)
# Out:
# Product Iphone price is 2500
# Product Laptop price is 3500

# %%
def price_list(**kwargs):
    for product in kwargs.items():
        title, price = product
        print(f'Product {title} price is {price}')

price_list(iphone=2500, laptop=3000, samsung=2000)
# Out:
# Product iphone price is 2500
# Product laptop price is 3000
# Product samsung price is 2000

# %% [markdown]
# ##rererere

# %% [markdown]
# ##dfdefd

# %% [markdown]
# Qisqartirish

# %% [markdown]
# ##effefe

# %%
def price_list(**kwargs):
    for title, price in kwargs.items():
        print(f'Product {title} price is {price}')

price_list(iphone=2500, laptop=3000, samsung=2000)
# Out:
# Product iphone price is 2500
# Product laptop price is 3000
# Product samsung price is 2000
